# %% [markdown]
# # Crygn: Only the controls were used for the overall analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
gene = 'Crygn'

# %%
manual = pd.read_csv(gene + '_manual_annotation.csv')
pd.set_option('display.max_columns', None)
manual
# Out:
#    mouse_id    strain sex genotype        type    bw  EF_manual  FS_manual  \
# 0  30508644  C57BL/6N   f  control  wt (Crygn)  21.2      92.24      63.01
# 1  30508645  C57BL/6N   f  control  wt (Crygn)  19.8      91.20      60.63
# 2  30508653  C57BL/6N   m  control  wt (Crygn)  26.7      87.83      56.17
# 3  30508700  C57BL/6N   m  control  wt (Crygn)  24.2      79.27      46.14
# 4  30508982  C57BL/6N   f  control  wt (Crygn)  21.3      88.68      57.06
#
#    LVIDd_manual  LVIDs_manual
# 0          2.77          1.05
# 1          2.44          0.99
# 2          2.80          1.30
# 3          2.80          1.58
# 4          2.68          1.15

# %%
filtered_data = pd.read_csv(gene + '_data_filtered_plus_functional_parameter_plus_manual_measurements.csv')
filtered_data
# Out:
#      mouse_id              file  LVIDd_auto  LVIDd_auto_time  LVIDs_auto  \
# 0    30508700  Crygn_2vX_50.dcm    2.703779         2.713333    1.279651
# 1    30508700  Crygn_2vX_50.dcm    2.641860         2.793333    1.197093
# 2    30508700  Crygn_2vX_50.dcm    2.497384         3.288333    1.424128
# 3    30508700  Crygn_2vX_50.dcm    2.910174         3.374167    1.197093
# 4    30508700  Crygn_2vX_50.dcm    3.034012         3.454167    0.846221
# ..        ...               ...         ...              ...         ...
# 320  30508644  Crygn_2vX_87.dcm    2.827616         4.465833    0.970058
# 321  30508644  Crygn_2vX_87.dcm    2.724419         4.554167    0.846221
# 322  30508644  Crygn_2vX_87.dcm    2.497384         4.642500    1.052616
# 323  30508644  Crygn_2vX_87.dcm    2.414826         4.722500    0.804942
# 324  30508653  Crygn_2vX_68.dcm    2.848256         3.890833    1.527326
#
#      LVIDs_auto_time  heart_rate_auto  heart_rate_auto_time  \
# 0           2.595000       750.000000              2.713333
# 1           2.669167       827.586207              2.793333
# 2           3.164167       699.029126              3.288333
# 3           3.250833       750.000000              3.374167
# 4           3.328333       699.029126              3.454167
# ..               ...              ...                   ...
# 320         4.415833       679.245283              4.465833
# 321         4.505000       679.245283              4.554167
# 322         4.585833       750.000000              4.642500
# 323         4.671667       660.550459              4.722500
# 324         4.081667       391.304348              3.890833
#
#      LVIDd_auto_quality_label LVIDd_auto_quality_flag  \
# 0                    0.675194                    high
# 1                    0.675194                    high
# 2                    0.531737                    high
# 3                    0.708001                    high
# 4                    0.708001                    high
# ..                        ...                     ...
# 320                  0.999670                    high
# 321                  0.999670                    high
# 322                  0.999804                    high
# 323                  0.999804                    high
# 324                  0.844666                    high
#
#      LVIDs_auto_quality_label LVIDs_auto_quality_flag  LV_Vold_auto  \
# 0                    0.675194                    high     27.109392
# 1                    0.675194                    high     25.599816
# 2                    0.531737                    high     22.263310
# 3                    0.531737                    high     32.489746
# 4                    0.531737                    high     35.977352
# ..                        ...                     ...           ...
# 320                  0.999670                    high     30.273021
# 321                  0.999670                    high     27.623261
# 322                  0.999670                    high     22.263310
# 323                  0.999804                    high     20.472684
# 324                  0.844666                    high     30.819105
#
#      LV_Vols_auto    EF_auto    FS_auto    strain sex genotype        type  \
# 0        3.986265  85.295631  52.671756  C57BL/6N   m  control  wt (Crygn)
# 1        3.338336  86.959531  54.687500  C57BL/6N   m  control  wt (Crygn)
# 2        5.287040  76.252227  42.975207  C57BL/6N   m  control  wt (Crygn)
# 3        3.338336  89.724954  58.865248  C57BL/6N   m  control  wt (Crygn)
# 4        1.306686  96.368032  72.108844  C57BL/6N   m  control  wt (Crygn)
# ..            ...        ...        ...       ...  ..      ...         ...
# 320      1.896068  93.736773  65.693431  C57BL/6N   f  control  wt (Crygn)
# 321      1.306686  95.269617  68.939394  C57BL/6N   f  control  wt (Crygn)
# 322      2.364612  89.378882  57.851240  C57BL/6N   f  control  wt (Crygn)
# 323      1.139125  94.435878  66.666667  C57BL/6N   f  control  wt (Crygn)
# 324      6.350326  79.394840  46.376812  C57BL/6N   m  control  wt (Crygn)
#
#        bw  EF_manual  FS_manual  LVIDd_manual  LVIDs_manual  dif_LVIDd  \
# 0    24.2      79.27      46.14          2.80          1.58  -0.096221
# 1    24.2      79.27      46.14          2.80          1.58  -0.158140
# 2    24.2      79.27      46.14          2.80          1.58  -0.302616
# 3    24.2      79.27      46.14          2.80          1.58   0.110174
# 4    24.2      79.27      46.14          2.80          1.58   0.234012
# ..    ...        ...        ...           ...           ...        ...
# 320  21.2      92.24      63.01          2.77          1.05   0.057616
# 321  21.2      92.24      63.01          2.77          1.05  -0.045581
# 322  21.2      92.24      63.01          2.77          1.05  -0.272616
# 323  21.2      92.24      63.01          2.77          1.05  -0.355174
# 324  26.7      87.83      56.17          2.80          1.30   0.048256
#
#      mean_LVIDd  dif_LVIDs  mean_LVIDs     dif_EF     dif_FS
# 0      2.751890  -0.300349    1.429826   6.025631   6.531756
# 1      2.720930  -0.382907    1.388547   7.689531   8.547500
# 2      2.648692  -0.155872    1.502064  -3.017773  -3.164793
# 3      2.855087  -0.382907    1.388547  10.454954  12.725248
# 4      2.917006  -0.733779    1.213110  17.098032  25.968844
# ..          ...        ...         ...        ...        ...
# 320    2.798808  -0.079942    1.010029   1.496773   2.683431
# 321    2.747209  -0.203779    0.948110   3.029617   5.929394
# 322    2.633692   0.002616    1.051308  -2.861118  -5.158760
# 323    2.592413  -0.245058    0.927471   2.195878   3.656667
# 324    2.824128   0.227326    1.413663  -8.435160  -9.793188
#
# [325 rows x 31 columns]

# %%
mice_manual = np.unique(manual['mouse_id'])
mice_automatic = np.unique(filtered_data['mouse_id'])
mice_manual==mice_automatic
# Out:
# array([ True,  True,  True,  True,  True])

# %%
mice_manual
# Out:
# array([30508644, 30508645, 30508653, 30508700, 30508982])

# %% [markdown]
# ## Differences between automatic and manual measurements

# %%
sns.set_style("whitegrid")
colors1="Spectral"
colors2="tab:red"

# %% [markdown]
# ### Overview per line

# %%
fig = plt.subplots(figsize= (30,20))
sns.boxplot(data=filtered_data,  x="mouse_id", y="LVIDd_auto", palette=colors1)
sns.stripplot(data= filtered_data, x = "mouse_id", y = "LVIDd_manual", color=colors2)

fig = plt.subplots(figsize= (30,20))
sns.boxplot(data=filtered_data,  x="mouse_id", y="LVIDs_auto", palette=colors1)
sns.stripplot(data= filtered_data, x = "mouse_id", y = "LVIDs_manual", color=colors2)
# Out:
# <AxesSubplot:xlabel='mouse_id', ylabel='LVIDs_manual'>

# %% [markdown]
# ### Overview per mouse per parameter

# %%
for mouse in mice_automatic:
    fig = plt.subplots(figsize= (10,10))
    sns.boxplot(data=filtered_data[filtered_data['mouse_id'] == mouse],  x="file", y="LVIDd_auto", palette=colors1)
    sns.stripplot(data= filtered_data[filtered_data['mouse_id'] == mouse], x = "file", y = "LVIDd_manual", color=colors2)
    plt.title(mouse)

    fig = plt.subplots(figsize= (10,10))
    sns.boxplot(data=filtered_data[filtered_data['mouse_id'] == mouse],  x="file", y="LVIDs_auto", palette=colors1)
    sns.stripplot(data= filtered_data[filtered_data['mouse_id'] == mouse], x = "file", y = "LVIDs_manual", color=colors2)
    plt.title(mouse)

# %% [markdown]
# ## Image quality

# %%
image_quality = pd.read_csv("../image_quality_all_files.csv")
image_quality = image_quality[image_quality['mouse_id'].isin(mice_manual)]
image_quality
# Out:
#      mouse_id     file_name  high_image_quality  low_image_quality
# 660  30508644  Crygn_2vX_88           94.707091           5.292909
# 661  30508644  Crygn_2vX_84           41.768032          58.231968
# 662  30508644  Crygn_2vX_87          100.000000           0.000000
# 663  30508644  Crygn_2vX_89           94.706185           5.293815
# 664  30508645  Crygn_2vX_78           10.585817          89.414183
# 665  30508645  Crygn_2vX_80           26.469077          73.530923
# 666  30508645  Crygn_2vX_82           21.175261          78.824739
# 667  30508645  Crygn_2vX_83           41.768032          58.231968
# 668  30508653  Crygn_2vX_66           10.587631          89.412369
# 669  30508653  Crygn_2vX_68            5.293815          94.706185
# 670  30508653  Crygn_2vX_70           31.192189          68.807811
# 671  30508700  Crygn_2vX_50           15.878726          84.121274
# 672  30508700  Crygn_2vX_51           10.587631          89.412369
# 673  30508700  Crygn_2vX_49            0.000000         100.000000
# 674  30508700  Crygn_2vX_52            5.293815          94.706185
# 675  30508700  Crygn_2vX_47            0.000000         100.000000
# 676  30508982  Crygn_2vX_20           41.768032          58.231968
# 677  30508982  Crygn_2vX_22           94.706185           5.293815
# 678  30508982  Crygn_2vX_19           15.298955          84.701045

# %% [markdown]
# ### Image quality per mouse

# %%
image_quality_mouse = image_quality.groupby(by = ['mouse_id']).mean().reset_index()
image_quality_mouse['mouse_id'] = image_quality_mouse['mouse_id'].astype(str)
image_quality_mouse.sort_values(by=['high_image_quality'], inplace = True)
labels = image_quality_mouse['mouse_id']
good_parts = image_quality_mouse['high_image_quality']
bad_parts = image_quality_mouse['low_image_quality']
width = 0.5   

fig, ax = plt.subplots(figsize=(15,10))

ax.bar(labels, good_parts, width, label='high', color='gold')
ax.bar(labels, bad_parts, width, bottom = good_parts, label='low', color='midnightblue')

ax.set_ylabel('in percent')
ax.set_title('Image quality per mouse')
ax.legend()

plt.show()

# %% [markdown]
# ### Image quality per line

# %%
image_quality = pd.DataFrame([[image_quality['high_image_quality'].describe()['mean'],
                             image_quality['low_image_quality'].describe()['mean']]], 
                             index = [gene],
                             columns= ['high image quality', 'low image quality'])
image_quality = image_quality.round(2)
image_quality
# Out:
#        high image quality  low image quality
# Crygn               34.83              65.17

# %% [markdown]
# ## Calculation of stats

# %%
# LVIDs diastole 
lvidd_stats = filtered_data[['dif_LVIDd']].describe()
lvidd_stats.rename(columns = {'dif_LVIDd': 'diff LVIDd'}, inplace=True)

# %%
# LVIDs systole
lvids_stats = filtered_data[['dif_LVIDs']].describe()
lvids_stats.rename(columns = {'dif_LVIDs': 'diff LVIDs'}, inplace=True)

# %%
# Ejection Fraction
ef_stats = filtered_data[['dif_EF']].describe()
ef_stats.rename(columns={'dif_EF':'diff ejection fraction'}, inplace=True)

# %%
# Fractional Shortening
fs_stats = filtered_data[['dif_FS']].describe()
fs_stats.rename(columns={'dif_FS':'diff fractional shortening'}, inplace=True)

# %%
stats_df = pd.concat([lvidd_stats,
                      lvids_stats,
                      ef_stats,
                      fs_stats
                     ],axis=1)
df = pd.DataFrame([[len(np.unique(filtered_data['mouse_id'])),
                    len(np.unique(filtered_data['mouse_id'])),
                    len(np.unique(filtered_data['mouse_id'])),
                    len(np.unique(filtered_data['mouse_id']))]], 
                  index = ['number of mice'],columns= stats_df.columns)
stats_df = stats_df.append(df)
stats_df.rename(index={'count':'number of measurements'}, inplace=True)
stats_df = stats_df.round(2)
stats_df
# Out:
#                         diff LVIDd  diff LVIDs  diff ejection fraction  \
# number of measurements      325.00      325.00                  325.00
# mean                         -0.01       -0.06                    0.29
# std                           0.23        0.23                    5.49
# min                          -0.71       -0.73                  -41.99
# 25%                          -0.15       -0.19                   -1.06
# 50%                          -0.02       -0.10                    1.46
# 75%                           0.10        0.00                    3.05
# max                           1.11        1.03                   17.10
# number of mice                5.00        5.00                    5.00
#
#                         diff fractional shortening
# number of measurements                      325.00
# mean                                          1.22
# std                                           7.35
# min                                         -37.05
# 25%                                          -1.94
# 50%                                           2.03
# 75%                                           5.56
# max                                          25.97
# number of mice                                5.00

# %%
# Creation of subgroups
f_man = manual[manual['sex'] == 'f']
m_man = manual[manual['sex'] == 'm']

# %%
means_auto = filtered_data.groupby(by = ['mouse_id', 'sex', 'genotype', 'type']).mean().reset_index()
means_auto_f = means_auto[means_auto['sex'] == 'f']
means_auto_m = means_auto[means_auto['sex'] == 'm']

# %%
num_stats = pd.DataFrame(
    [[len(f_man[f_man['genotype'] == 'control']),
      len(means_auto_f[means_auto_f['genotype'] == 'control'])],
     [len(m_man[m_man['genotype'] == 'control']),
      len(means_auto_m[means_auto_m['genotype'] == 'control'])
    ]],
    index = ['f', 'm'], 
    columns = ['man con', 'auto con']
)
num_stats
# Out:
#    man con  auto con
# f        3         3
# m        2         2

# %%
image_quality.to_csv(gene + '_image_quality_per_line.csv')
num_stats.to_csv(gene + '_number_of_mice.csv')
